# %% [markdown]
# # Analysis MSC results

# %%
import pandas as pd
from pathlib import Path

# %%
msc_folder  = Path("../../../malayalam_msc_benchmarking/")

# %%
[x for x in msc_folder.iterdir() if x.suffix ==".parquet"]
# Out:
# [PosixPath('../../../malayalam_msc_benchmarking/thennal_whisper-medium-ml_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/openai_whisper-tiny_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/openai_whisper-medium_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/anuragshas_whisper-large-v2-ml_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/openai_whisper-base_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/parambharat_whisper-base-ml_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/parambharat_whisper-small-ml_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/openai_whisper-large_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/openai_whisper-large-v2_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/parambharat_whisper-tiny-ml_msc.parquet'),
#  PosixPath('../../../malayalam_msc_benchmarking/openai_whisper-small_msc.parquet'),
# ...

# %% [markdown]
# ## Param Bharath Models

# %%
(msc_folder/("parambharat_whisper-tiny-ml_msc.parquet")).exists()
# Out:
# True

# %%
param_tiny = pd.read_parquet(msc_folder/("parambharat_whisper-tiny-ml_msc.parquet"))
param_tiny.head()
# Out:
#                                          predictions
# 0                       അണ ണ ൻ മ ദ ല മര ഗ റ റ മറക ക   \
# 1  ആന ത ന യ ട പല ല ന ശ രവര പണ ട യ പ ല പല ക ക ന ന ...
# 2                       ചങ ങള ക ക ബ ര ന ദ വ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                        വ ത ത ള ച ന ന ൽ പത ത യന നറ
#
#                                         ground_truth
# 0                   അണ ണ ൻ മ ത ത ല മര ക റ റ മറക ക മ   \
# 1  പ ണ ടൻ ന യ ട പല ല ന ശ ര യ പണ ട പ ല ഫല യ ‌ക ക ന...
# 2                      ചങ ങലയ ക ക ഭ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                       വ ത ത ഴ ച ന ന ൽ പത ത യ ന റയ
#
#                     model_name       wer       cer  total_time  total_wer
# 0  parambharat/whisper-tiny-ml  0.285714  0.193548  727.569748      43.96  \
# 1  parambharat/whisper-tiny-ml  0.375000  0.250000  727.569748      43.96
# 2  parambharat/whisper-tiny-ml  0.307692  0.178571  727.569748      43.96
# ...

# %%
param_base = pd.read_parquet(msc_folder/("parambharat_whisper-base-ml_msc.parquet"))
param_base.head()
# Out:
#                                          predictions
# 0                   അണ ണ ൻ മ ദ ധ ല മര ഖ യ റ റ മറക ക   \
# 1  ആണ റ ൻറ ആയ ട പല നശ ശവ ര പണ ട പ ല പ ല ക ക ന ന ല ല
# 2                       ചങ ങള ക ക ബ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                     വ ട ട ആള ച ന ന ൽ പത ത യ ന നടയ
#
#                                         ground_truth
# 0                   അണ ണ ൻ മ ത ത ല മര ക റ റ മറക ക മ   \
# 1  പ ണ ടൻ ന യ ട പല ല ന ശ ര യ പണ ട പ ല ഫല യ ‌ക ക ന...
# 2                      ചങ ങലയ ക ക ഭ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                       വ ത ത ഴ ച ന ന ൽ പത ത യ ന റയ
#
#                     model_name       wer       cer   total_time model_size
# 0  parambharat/whisper-base-ml  0.357143  0.225806  1124.313922     72.59M
# 1  parambharat/whisper-base-ml  0.500000  0.326923  1124.313922     72.59M
# 2  parambharat/whisper-base-ml  0.153846  0.107143  1124.313922     72.59M
# ...

# %%
param_small = pd.read_parquet(msc_folder/("parambharat_whisper-small-ml_msc.parquet"))
param_small.head()
# Out:
#                                          predictions
# 0                    അണ ണ ൻ മ ദ ധ ല മരങ ക റ റ മറക ക   \
# 1  ആദ യന ന യയ ട പല യ ന ന ശവ ര പണ ട പ പ ള പല ക ക ന...
# 2                        ചങ ങള ക ക ബ ര ഗത പ ട ച ച ല
# 3                         അണ ണ ൻ ക ഞ ഞ തന ന ല ‍ ഹയത
# 4                   വ ട ട ഴൻ ച ന നൽ പട ട യ ര ന നറ യ
#
#                                         ground_truth
# 0                   അണ ണ ൻ മ ത ത ല മര ക റ റ മറക ക മ   \
# 1  പ ണ ടൻ ന യ ട പല ല ന ശ ര യ പണ ട പ ല ഫല യ ‌ക ക ന...
# 2                      ചങ ങലയ ക ക ഭ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                       വ ത ത ഴ ച ന ന ൽ പത ത യ ന റയ
#
#                      model_name       wer       cer   total_time model_size
# 0  parambharat/whisper-small-ml  0.285714  0.161290  2893.444937    241.73M
# 1  parambharat/whisper-small-ml  0.500000  0.326923  2893.444937    241.73M
# 2  parambharat/whisper-small-ml  0.307692  0.178571  2893.444937    241.73M
# ...

# %% [markdown]
# ## Thennal model

# %%
thennal_df = pd.read_parquet(msc_folder/("thennal_whisper-medium-ml_msc.parquet"))
thennal_df.head()
# Out:
#                                          predictions
# 0                   അണ ണ ൻ മ ത ത ല മര ക റ റ മറക ക മ   \
# 1  പ ണ ടൻ ന യ ട പല ല ന ശ ര യ പണ ട പ ല ഫല യ ‌ക ക ന...
# 2                      ചങ ങലയ ക ക ഭ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                       വ ത ത ഴ ച ന ന ൽ പത ത യ ന റയ
#
#                                         ground_truth
# 0                   അണ ണ ൻ മ ത ത ല മര ക റ റ മറക ക മ   \
# 1  പ ണ ടൻ ന യ ട പല ല ന ശ ര യ പണ ട പ ല ഫല യ ‌ക ക ന...
# 2                      ചങ ങലയ ക ക ഭ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                       വ ത ത ഴ ച ന ന ൽ പത ത യ ന റയ
#
#                   model_name  wer  cer   total_time model_size
# 0  thennal/whisper-medium-ml  0.0  0.0  8736.730867    763.86M
# 1  thennal/whisper-medium-ml  0.0  0.0  8736.730867    763.86M
# 2  thennal/whisper-medium-ml  0.0  0.0  8736.730867    763.86M
# 3  thennal/whisper-medium-ml  0.0  0.0  8736.730867    763.86M
# ...

# %% [markdown]
# ## Drishti Sharma model

# %%
drishti_df = pd.read_parquet(msc_folder/("DrishtiSharma_whisper-large-v2-malayalam_msc.parquet"))
drishti_df.head()
# Out:
#                                          predictions
# 0                    അണ ണ ന മ ത ത ല മരങ ക ട ട മറക ക   \
# 1  മ ന ട ന ന യ ട പല ല ന ശവര പണ ടയ പ ല ഫല ക ക ന ന ...
# 2                        ചങ ങളക ക ബ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ന ക ഞ ഞ തന ന ല യത
# 4                        ന ത ത ഴ ച ന ന ൽ പത ത യന നറ
#
#                                         ground_truth
# 0                   അണ ണ ൻ മ ത ത ല മര ക റ റ മറക ക മ   \
# 1  പ ണ ടൻ ന യ ട പല ല ന ശ ര യ പണ ട പ ല ഫല യ ‌ക ക ന...
# 2                      ചങ ങലയ ക ക ഭ ര ന ത പ ട ച ച ല
# 3                            അണ ണ ൻ ക ഞ ഞ തന ന ല യത
# 4                       വ ത ത ഴ ച ന ന ൽ പത ത യ ന റയ
#
#                                  model_name       wer       cer    total_time
# 0  DrishtiSharma/whisper-large-v2-malayalam  0.357143  0.193548  10067.009426  \
# 1  DrishtiSharma/whisper-large-v2-malayalam  0.416667  0.211538  10067.009426
# 2  DrishtiSharma/whisper-large-v2-malayalam  0.230769  0.142857  10067.009426
# ...
