# %%
import pandas as pd

# %%
df = pd.read_parquet("/home/malayalam_common_voice_benchmarking/commonvoice_benchmarking_results.parquet")
df.head()
# Out:
#                                      models    wer    cer model size  \
# 0                 thennal/whisper-medium-ml  11.56   5.41    763.86M
# 1            anuragshas/whisper-large-v2-ml  24.46  11.64      1.54B
# 2              parambharat/whisper-small-ml  21.65  11.78    241.73M
# 3  DrishtiSharma/whisper-large-v2-malayalam  26.25  13.17      1.54B
# 4               parambharat/whisper-base-ml  30.33  16.16     72.59M
#
#        time(s)
# 0   924.979711
# 1  1779.561592
# 2   273.555688
# 3  1773.661774
# 4    96.419609

# %%
df.head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_4ca18_row0_col1, #T_4ca18_row0_col2, #T_4ca18_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_4ca18_row0_col4 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_4ca18_row1_col1, #T_4ca18_row2_col4 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_4ca18_row1_col2, #T_4ca18_row2_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_4ca18_row1_col4, #T_4ca18_row3_col4 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_4ca18_row2_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_4ca18_row3_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_4ca18_row3_col2 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_4ca18_row4_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_4ca18_row4_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_4ca18_row4_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# ...

# %% [markdown]
# ## Looking at results of Kurian Benoy ASR

# %%
kurian_asr = pd.read_parquet("/home/malayalam_common_voice_benchmarking/kurianbenoy_whisper_malayalam_largev2_commonvoice.parquet")
kurian_asr.head()
# Out:
#                                          predictions  \
# 0  ഇന ത ര വത ത ത ന ത ടര ന ന ണ ട യ സ വ ക ക വ ര ത ക...
# 1   ന ത ട യ നൽക ന നത ക ണ ട ര ഗത ത ല ക ക ള ള മ റ റ...
# 2   ന ത ന ഒര ക ല കടതന ന ങ ങള ട ത ണ എന ത ന ഒര ക ല ...
# 3   ന പ പയ ട ഒര വ ട കണ ട ത ത ന വ ല യ സ രമ നടക ക ന ന
# 4   ത ക അത ക ണ ട പ യ ക ടക ക അത ക അത ക ണ ട പ യ ക ട...
#
#                                         ground_truth  \
# 0  ഇന ദ ര വധത ത ന ത ടര ന ന ണ ട യ സ ഖ വ ര ദ ധ കല പ...
# 1  പ ന ത ണയ നല ക ന നത ക ണ ട ര ഗത ത ല ക ക ള ള മ റ ...
# 2              എന ത ന ഒര ക ല ഈ കട തന ന ന ങ ങള ട ത ണ
# 3       ന പയ ട ഉറവ ട കണ ട ത ത ന വല യ ശ രമ നടക ക ന ന
# 4                          അത ക അത ക ണ ട പ യ ക ടക ക
#
#                               model_name       wer       cer   total_time  \
# 0  kurianbenoy/whisper_malayalam_largev2  0.313725  0.150000  5034.771624
# 1  kurianbenoy/whisper_malayalam_largev2  0.358974  0.211111  5034.771624
# 2  kurianbenoy/whisper_malayalam_largev2  4.125000  4.305556  5034.771624
# ...

# %%
kurian_asr["wer"]
# Out:
# 0       0.313725
# 1       0.358974
# 2       4.125000
# 3       0.333333
# 4       3.909091
#          ...
# 107     0.428571
# 108    15.750000
# 109     8.111111
# 110     0.342857
# 111     0.368421
# Name: wer, Length: 112, dtype: float64
