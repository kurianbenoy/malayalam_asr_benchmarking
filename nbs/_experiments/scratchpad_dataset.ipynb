# %%
! pip install -Uqq datasets transformers jiwer
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 20.9 MB/s eta 0:00:00

# %%
from datasets import load_dataset
from datasets import get_dataset_split_names

# %%
## Calculate results across Mozilla Common Voice and Malayalam Speech Corpus

# %%
dataset = load_dataset("thennal/msc")
# Out:
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/thennal___parquet/thennal--msc-cc9d10989b2ac4bd/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_df =dataset["train"].to_pandas()
train_df.shape
# Out:
# (1541, 8)

# %%
dataset = load_dataset("mozilla-foundation/common_voice_11_0", "ml")
# Out:
# ...
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 430it [00:00, 78163.77it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 112it [00:00, 68378.76it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 1939it [00:00, 73821.40it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 11it [00:00, 36472.21it/s]
# Dataset common_voice_11_0 downloaded and prepared to /root/.cache/huggingface/datasets/mozilla-foundation___common_voice_11_0/ml/11.0.0/2c65b95d99ca879b1b1074ea197b65e0497848fd697fdb0582e0f6b75b6f4da0. Subsequent calls will reuse this data.
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
dataset["train"][0]
# Out:
# {'client_id': '29ca16eb2c0faea0be0ad73b5d826f5e81dc6fd4acfa9241a002b5d3619fd51c5b00b009e7b98b50caa5829f8a96697d5942b120749ee63a5d637c632bd0f7bc',
#  'path': '/root/.cache/huggingface/datasets/downloads/extracted/7a5483e18eadf711d9e766a084a54317359e0c06c24e82760bfe23139091a2f4/common_voice_ml_28913601.mp3',
#  'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/7a5483e18eadf711d9e766a084a54317359e0c06c24e82760bfe23139091a2f4/common_voice_ml_28913601.mp3',
#   'array': array([-5.9054565e-16, -5.8716256e-14, -5.4170010e-15, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 48000},
#  'sentence': 'എന്തുകൊണ്ട് യുവാക്കൾ കൂടുതൽ രാഷ്ട്രീയമായി ചിന്തിക്കണം, എന്തുകൊണ്ട് അവർ സംഘടിതരാകണം എന്നതിന്റെ ഉദാത്തമായ ഉദാഹരണമാകുന്നു കേരളം.',
#  'up_votes': 2,
#  'down_votes': 0,
#  'age': '',
#  'gender': '',
#  'accent': '',
#  'locale': 'ml',
#  'segment': ''}

# %%
x = dataset["train"]
train_df =dataset["train"].to_pandas()

# %%
type(x)
# Out:
# datasets.arrow_dataset.Dataset

# %%
train_df.head()
# Out:
#                                            client_id  \
# 0  29ca16eb2c0faea0be0ad73b5d826f5e81dc6fd4acfa92...
# 1  29ca16eb2c0faea0be0ad73b5d826f5e81dc6fd4acfa92...
# 2  29ca16eb2c0faea0be0ad73b5d826f5e81dc6fd4acfa92...
# 3  29ca16eb2c0faea0be0ad73b5d826f5e81dc6fd4acfa92...
# 4  29ca16eb2c0faea0be0ad73b5d826f5e81dc6fd4acfa92...
#
#                                                 path  \
# 0  /root/.cache/huggingface/datasets/downloads/ex...
# 1  /root/.cache/huggingface/datasets/downloads/ex...
# 2  /root/.cache/huggingface/datasets/downloads/ex...
# 3  /root/.cache/huggingface/datasets/downloads/ex...
# 4  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                audio  \
# 0  {'bytes': b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x...
# 1  {'bytes': b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x...
# 2  {'bytes': b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x...
# 3  {'bytes': b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x...
# ...

# %%
train_df.shape
# Out:
# (430, 11)

# %%
dataset["train"][0]
# Out:
# {'speechid': '0I2iIh7OSMdWhvb85tMp',
#  'speaker_id': 'oeaNxrE0uxNSfoDpdrCYGBGC7uC3',
#  'review_score': 42,
#  'transcript': 'അണ്ണാൻ മൂത്താലും മരം കേറ്റം മറക്കുമോ?',
#  'category': 'proverb',
#  'speaker_gender': 'default',
#  'speaker_age': 'default',
#  'audio': {'path': None,
#   'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -3.05175781e-05, -3.05175781e-05, -3.05175781e-05]),
#   'sampling_rate': 48000}}

# %%
iterable_dataset   = load_dataset("thennal/msc", split="train", streaming=True)
for example in iterable_dataset:

    print(example)
# Out:
# {'speechid': '0I2iIh7OSMdWhvb85tMp', 'speaker_id': 'oeaNxrE0uxNSfoDpdrCYGBGC7uC3', 'review_score': 42, 'transcript': 'അണ്ണാൻ മൂത്താലും മരം കേറ്റം മറക്കുമോ?', 'category': 'proverb', 'speaker_gender': 'default', 'speaker_age': 'default', 'audio': {'path': None, 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#        -3.05175781e-05, -3.05175781e-05, -3.05175781e-05]), 'sampling_rate': 48000}}
# {'speechid': '0Gbc6JQLVd6ah2P5Nz0D', 'speaker_id': '6FzGR8AJFJSEml6AIs55fEgJmqX2', 'review_score': 30, 'transcript': 'പാണ്ടൻ നായുടെ പല്ലിനു ശൗര്യം പണ്ടേപോല ഫലിയ്\u200cക്കുന്നില്ല.', 'category': 'proverb', 'speaker_gender': 'default', 'speaker_age': 'default', 'audio': {'path': None, 'array': array([ 0.        ,  0.        ,  0.        , ..., -0.00042725,
#        -0.00036621, -0.00030518]), 'sampling_rate': 48000}}
# ...

# %%
from transformers import AutoProcessor, AutoModelForSpeechSeq2Seq

processor = AutoProcessor.from_pretrained("kurianbenoy/whisper_malayalam_largev2")

model = AutoModelForSpeechSeq2Seq.from_pretrained("kurianbenoy/whisper_malayalam_largev2")
