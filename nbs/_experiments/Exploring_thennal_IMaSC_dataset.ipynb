# %%
! pip install -Uqq datasets transformers jiwer
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 58.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 43.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 27.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 21.0 MB/s eta 0:00:00

# %%
from datasets import load_dataset

dataset = load_dataset("thennal/IMaSC")
# Out:
# ...
# Generating train split:   0%|          | 0/34473 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/thennal___parquet/thennal--IMaSC-6aa263ba5427fffe/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'speaker', 'audio'],
#         num_rows: 34473
#     })
# })

# %%
train_df =dataset["train"].to_pandas()
train_df.shape
# Out:
# (34473, 3)

# %%
train_df["text"].unique()
# Out:
# array(['സർവ്വകലാശാല വൈസ് ചാൻസലർ ഡോ. ചന്ദ്രബാബുവിനും സംഭവം തലവേദനയാവുകയാണ്',
#        'സുരക്ഷാ നടപടികളുടെ ഭാഗമായി ഇരുവരെയും നെടുമ്പാശേരി പോലീസിനു കൈമാറി',
#        'സാമൂഹ്യനീതി ഡയറക്ടർക്കാണ് കമ്മിഷൻ അംഗം പി. മോഹനദാസ് നിർദേശം നൽകിയത്',
#        ...,
#        'തീക്ഷണമായ സമരത്തിന്റെ ഫലമായി കമ്പനി അടിച്ചുപൂട്ടാൻ കൊക്കക്കോള നിർബന്ധിതമായി',
#        'അവയിൽ ആനിമേഷൻ ചലചിത്രങ്ങളും നാടക ചിത്രങ്ങളും ഷോകളും ഉൽപ്പെടുന്നു',
#        'സർദാർ ഹിമ്മത്ത് സിങ്ങിന്റെ നേതൃത്വത്തിലുള്ള പിന്നീട് ഇവിടം പിടിച്ചെടുക്കുകയുണ്ടായി'],
#       dtype=object)

# %%
type(train_df["text"].unique())
# Out:
# numpy.ndarray

# %%
len(train_df["text"].unique())
# Out:
# 8854

# %%
train_df["speaker"].unique()
# Out:
# array(['Sonia', 'Anil', 'Sonu', 'Simla', 'Vidhya', 'Jijo', 'Greeshma',
#        'Joji'], dtype=object)
